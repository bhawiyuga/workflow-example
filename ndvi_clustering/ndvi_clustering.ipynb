# %% [markdown]
# # NDVI Clustering Analysis
#
# This notebook demonstrates K-means clustering on NDVI (Normalized Difference Vegetation Index) data to identify different vegetation patterns or zones.
#
# We'll use scikit-learn's K-means implementation to cluster NDVI values from GeoTIFF files.

# %%
import os
import sys
import numpy as np
import matplotlib.pyplot as plt
import rasterio
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
import geopandas as gpd
from pathlib import Path

# Add current directory to path
sys.path.append('.')

# Import our clustering module
from ndvi_clustering import (load_ndvi_raster, preprocess_for_clustering,
                            apply_kmeans, create_clustered_image, apply_sieve_filter,
                            save_clustered_image, create_cluster_visualization)

# %matplotlib inline

# %% [markdown]
# ## Load NDVI Data
#
# First, let's load an NDVI GeoTIFF file. You can use the NDVI generated from the monthly_ndvi_calculation module.

# %%
# Define the path to the NDVI file
ndvi_file_path = "../monthly_ndvi_calculation/monthly_max_ndvi.tif"

# Check if file exists
if not os.path.exists(ndvi_file_path):
    print(f"Warning: {ndvi_file_path} does not exist. Please run the NDVI calculation first.")
else:
    print(f"NDVI file found: {ndvi_file_path}")
# Out:
# NDVI file found: ../monthly_ndvi_calculation/monthly_max_ndvi.tif

# %%
# Load the NDVI data
ndvi_array, profile = load_ndvi_raster(ndvi_file_path)

# Display basic information
print(f"NDVI array shape: {ndvi_array.shape}")
print(f"NDVI value range: {np.nanmin(ndvi_array):.4f} to {np.nanmax(ndvi_array):.4f}")
print(f"NDVI mean value: {np.nanmean(ndvi_array):.4f}")

# Visualize the NDVI raster
plt.figure(figsize=(10, 8))
plt.imshow(ndvi_array, cmap='RdYlGn', vmin=-1, vmax=1)
plt.colorbar(label='NDVI')
plt.title('NDVI Values')
plt.axis('off')
plt.show()
# Out:
# 2025-08-22 10:00:28,761 - ndvi_clustering - INFO - Loading NDVI data from ../monthly_ndvi_calculation/monthly_max_ndvi.tif
# 2025-08-22 10:00:28,839 - ndvi_clustering - INFO - NDVI data loaded with shape (1099, 1098)
# 2025-08-22 10:00:28,839 - ndvi_clustering - INFO - NDVI data loaded with shape (1099, 1098)
# NDVI array shape: (1099, 1098)
# NDVI value range: -0.9414 to 0.9835
# NDVI mean value: -0.5326

# %% [markdown]
# ## Preprocess Data for Clustering
#
# Next, we'll preprocess the NDVI data to prepare it for clustering. This involves:
# 1. Removing invalid values (NaN, values outside [-1, 1])
# 2. Standardizing the features

# %%
# Preprocess the data
features, mask = preprocess_for_clustering(ndvi_array)

# Display preprocessing results
print(f"Original data shape: {ndvi_array.shape}")
print(f"Valid pixels for clustering: {features.shape[0]}")
print(f"Feature shape after preprocessing: {features.shape}")
print(f"Valid pixels percentage: {np.sum(mask) / mask.size * 100:.2f}%")
# Out:
# 2025-08-22 10:00:33,230 - ndvi_clustering - INFO - Preprocessing NDVI data for clustering
# 2025-08-22 10:00:33,245 - ndvi_clustering - INFO - Preprocessed 1199783 valid NDVI points
# 2025-08-22 10:00:33,245 - ndvi_clustering - INFO - Preprocessed 1199783 valid NDVI points
# Original data shape: (1099, 1098)
# Valid pixels for clustering: 1199783
# Feature shape after preprocessing: (1199783, 1)
# Valid pixels percentage: 99.43%

# %% [markdown]
# ## Determine Optimal Number of Clusters
#
# Let's use the Elbow Method to determine the optimal number of clusters for our data.

# %%
# Calculate inertia (sum of squared distances) for different numbers of clusters
inertia = []
k_range = range(2, 11)

for k in k_range:
    kmeans = KMeans(n_clusters=k, random_state=42, n_init=10)
    kmeans.fit(features)
    inertia.append(kmeans.inertia_)

# Plot the Elbow curve
plt.figure(figsize=(10, 6))
plt.plot(k_range, inertia, 'bo-')
plt.xlabel('Number of clusters')
plt.ylabel('Inertia')
plt.title('Elbow Method for Optimal k')
plt.grid(True)
plt.show()

# %% [markdown]
# Based on the Elbow curve, select an appropriate number of clusters. The "elbow point" is where adding more clusters doesn't significantly reduce the inertia.

# %%
# Define the number of clusters to use
n_clusters = 5  # Adjust this based on the Elbow curve
print(f"Using {n_clusters} clusters for K-means clustering")
# Out:
# Using 5 clusters for K-means clustering

# %% [markdown]
# ## Apply K-means Clustering

# %%
# Apply K-means clustering
cluster_labels, cluster_centers = apply_kmeans(features, n_clusters=n_clusters)

# Display cluster information
print(f"Cluster centers (standardized):\n")
for i, center in enumerate(cluster_centers):
    print(f"Cluster {i}: {center[0]:.4f}")

# Count the number of pixels in each cluster
unique, counts = np.unique(cluster_labels, return_counts=True)
cluster_counts = dict(zip(unique, counts))

# Display counts and percentages
print("\nCluster distribution:")
for cluster, count in cluster_counts.items():
    percentage = count / len(cluster_labels) * 100
    print(f"Cluster {cluster}: {count} pixels ({percentage:.2f}%)")
# Out:
# 2025-08-22 10:04:12,091 - ndvi_clustering - INFO - Applying K-means clustering with 5 clusters
# 2025-08-22 10:04:13,511 - ndvi_clustering - INFO - K-means clustering completed
# 2025-08-22 10:04:13,511 - ndvi_clustering - INFO - K-means clustering completed
# Cluster centers (standardized):
#
# Cluster 0: 0.4762
# Cluster 1: -0.9784
# Cluster 2: 1.3490
# Cluster 3: 3.9288
# Cluster 4: -0.2665
#
# Cluster distribution:
# Cluster 0: 280408 pixels (23.37%)
# Cluster 1: 361553 pixels (30.13%)
# Cluster 2: 164454 pixels (13.71%)
# Cluster 3: 24732 pixels (2.06%)
# Cluster 4: 368636 pixels (30.73%)

# %% [markdown]
# ## Create Clustered Image

# %%
# Create clustered image
clustered_image = create_clustered_image(ndvi_array, mask, cluster_labels, n_clusters)

# Apply sieve filter to remove small isolated clusters
min_size = 10  # Minimum size of clusters to keep
filtered_image = apply_sieve_filter(clustered_image, min_size=min_size)
# Out:
# 2025-08-22 10:04:19,808 - ndvi_clustering - INFO - Creating clustered image
# 2025-08-22 10:04:19,811 - ndvi_clustering - INFO - Clustered image created
# 2025-08-22 10:04:19,812 - ndvi_clustering - INFO - Applying sieve filter with minimum size 10
# 2025-08-22 10:04:19,811 - ndvi_clustering - INFO - Clustered image created
# 2025-08-22 10:04:19,812 - ndvi_clustering - INFO - Applying sieve filter with minimum size 10
# 2025-08-22 10:04:19,875 - ndvi_clustering - INFO - Sieve filtering completed
# 2025-08-22 10:04:19,875 - ndvi_clustering - INFO - Sieve filtering completed

# %% [markdown]
# ## Visualize Clustering Results

# %%
# Create a visualization with both original NDVI and clustered result
plt.figure(figsize=(16, 8))

# Plot original NDVI
plt.subplot(1, 2, 1)
plt.imshow(ndvi_array, cmap='RdYlGn', vmin=-1, vmax=1)
plt.colorbar(label='NDVI')
plt.title('Original NDVI')
plt.axis('off')

# Plot clustered image
plt.subplot(1, 2, 2)
masked_clusters = np.ma.masked_where(filtered_image == -9999, filtered_image)
plt.imshow(masked_clusters, cmap='viridis', vmin=0, vmax=n_clusters-1)
plt.colorbar(label='Cluster ID')
plt.title('NDVI Clusters')
plt.axis('off')

plt.tight_layout()
plt.show()

# Create more detailed visualization
output_dir = "output"
os.makedirs(output_dir, exist_ok=True)
vis_output = os.path.join(output_dir, "ndvi_clusters_visualization.png")
create_cluster_visualization(filtered_image, cluster_centers, vis_output, original_ndvi=ndvi_array)
# Out:
# 2025-08-22 10:04:28,255 - ndvi_clustering - INFO - Creating cluster visualization to output/ndvi_clusters_visualization.png
# 2025-08-22 10:04:29,525 - ndvi_clustering - INFO - Cluster visualization saved to output/ndvi_clusters_visualization.png
# 2025-08-22 10:04:29,525 - ndvi_clustering - INFO - Cluster visualization saved to output/ndvi_clusters_visualization.png

# %% [markdown]
# ## Save Clustered Results

# %%
# Save the clustered image as a GeoTIFF
output_dir = "output"
os.makedirs(output_dir, exist_ok=True)
output_path = os.path.join(output_dir, "clustered_ndvi.tif")

save_clustered_image(filtered_image, profile, output_path)
print(f"Clustered NDVI saved to {output_path}")
# Out:
# 2025-08-22 10:04:39,022 - ndvi_clustering - INFO - Saving clustered image to output/clustered_ndvi.tif
# 2025-08-22 10:04:39,091 - ndvi_clustering - INFO - Clustered image saved to output/clustered_ndvi.tif
# 2025-08-22 10:04:39,091 - ndvi_clustering - INFO - Clustered image saved to output/clustered_ndvi.tif
# Clustered NDVI saved to output/clustered_ndvi.tif

# %% [markdown]
# ## Interpret Clusters
#
# Let's analyze what each cluster might represent in terms of vegetation or land cover.

# %%
# Create a function to map standardized cluster centers back to NDVI values
def interpret_cluster(cluster_id, cluster_centers):
    # Get all NDVI values for this cluster
    cluster_mask = (filtered_image == cluster_id) & mask
    if not np.any(cluster_mask):
        return None
    
    cluster_ndvi = ndvi_array[cluster_mask]
    
    # Calculate statistics
    mean_ndvi = np.mean(cluster_ndvi)
    min_ndvi = np.min(cluster_ndvi)
    max_ndvi = np.max(cluster_ndvi)
    std_ndvi = np.std(cluster_ndvi)
    
    # Land cover interpretation based on NDVI ranges
    if mean_ndvi < -0.1:
        interpretation = "Water or shadows"
    elif mean_ndvi < 0.2:
        interpretation = "Bare soil or urban areas"
    elif mean_ndvi < 0.4:
        interpretation = "Sparse vegetation or grassland"
    elif mean_ndvi < 0.6:
        interpretation = "Moderate vegetation or cropland"
    else:
        interpretation = "Dense vegetation or forest"
    
    return {
        "cluster_id": cluster_id,
        "mean_ndvi": mean_ndvi,
        "min_ndvi": min_ndvi,
        "max_ndvi": max_ndvi,
        "std_ndvi": std_ndvi,
        "interpretation": interpretation
    }

# Interpret each cluster
cluster_interpretations = []
for i in range(n_clusters):
    result = interpret_cluster(i, cluster_centers)
    if result:
        cluster_interpretations.append(result)

# Sort clusters by mean NDVI
cluster_interpretations.sort(key=lambda x: x["mean_ndvi"])

# Display interpretation
print("Cluster Interpretations:\n")
for ci in cluster_interpretations:
    print(f"Cluster {ci['cluster_id']}:")
    print(f"  Mean NDVI: {ci['mean_ndvi']:.4f}")
    print(f"  Range: {ci['min_ndvi']:.4f} to {ci['max_ndvi']:.4f} (std: {ci['std_ndvi']:.4f})")
    print(f"  Interpretation: {ci['interpretation']}")
    print()
# Out:
# Cluster Interpretations:
#
# Cluster 1:
#   Mean NDVI: -0.7118
#   Range: -0.9414 to 0.6465 (std: 0.1330)
#   Interpretation: Water or shadows
#
# Cluster 4:
#   Mean NDVI: -0.5786
#   Range: -0.9160 to 0.9767 (std: 0.1062)
#   Interpretation: Water or shadows
#
# Cluster 0:
#   Mean NDVI: -0.4270
#   Range: -0.9140 to 0.8065 (std: 0.1076)
#   Interpretation: Water or shadows
#
# Cluster 2:
#   Mean NDVI: -0.2601
#   Range: -0.9185 to 0.7073 (std: 0.1536)
#   Interpretation: Water or shadows
#
# Cluster 3:
#   Mean NDVI: 0.2552
#   Range: -0.8881 to 0.9835 (std: 0.3506)
#   Interpretation: Sparse vegetation or grassland

# %% [markdown]
# ## Conclusion
#
# In this notebook, we've performed K-means clustering on NDVI data to identify different vegetation or land cover types. The clusters represent areas with similar NDVI values, which can be interpreted as different vegetation densities or land cover types.
#
# The clustering results can be used for further analysis, such as:
# - Vegetation zone mapping
# - Land cover classification
# - Monitoring vegetation changes over time
# - Agricultural management zones
